# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
##load csv
orig_jobs= pd.read_csv("occupational_salary_filtered.csv")

orig_jobs = orig_jobs[orig_jobs['a_mean'] != "*"]

orig_jobs['a_mean'] = pd.to_numeric(orig_jobs['a_mean'])
orig_jobs.head()
# Out:
#     area   area_title  area_type  naics     naics_title         i_group  \
# 0  10180  Abilene, TX          4      0  Cross-industry  cross-industry
# 1  10180  Abilene, TX          4      0  Cross-industry  cross-industry
# 2  10180  Abilene, TX          4      0  Cross-industry  cross-industry
# 3  10180  Abilene, TX          4      0  Cross-industry  cross-industry
# 4  10180  Abilene, TX          4      0  Cross-industry  cross-industry
#
#    own_code occ_code                                  occ_title   o_group  \
# 0      1235   Nov-21  Computer and Information Systems Managers  detailed
# 1      1235  15-0000      Computer and Mathematical Occupations     major
# 2      1235  15-1211                  Computer Systems Analysts  detailed
# 3      1235  15-1231       Computer Network Support Specialists  detailed
# 4      1235  15-1232          Computer User Support Specialists  detailed
#
#    ... h_median h_pct75 h_pct90 a_pct10  a_pct25 a_median  a_pct75 a_pct90  \
# 0  ...    50.17   69.41   93.63   56260    74910   104350   144370  194760
# 1  ...    27.31   36.98   49.45   34510    44600    56810    76910  102860
# 2  ...    28.77   39.04   46.91   42410    47350    59840    81200   97580
# 3  ...    23.23   27.71      31   35460    39530    48330    57630   64470
# 4  ...    21.63   26.18   30.01   27850    35130    44980    54450   62420
#
#   annual hourly
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
# [5 rows x 30 columns]

# %%
##grouping by area_title which will be used to match by location 
groupby_data = round(orig_jobs.groupby(['area_title']).mean(),2)
groupby_data.head()
# Out:
#                           area  area_type  naics  own_code  pct_total  \
# area_title
# Abilene, TX            10180.0        4.0    0.0    1235.0        NaN
# Aguadilla-Isabela, PR  10380.0        4.0    0.0    1235.0        NaN
# Akron, OH              10420.0        4.0    0.0    1235.0        NaN
# Albany, GA             10500.0        4.0    0.0    1235.0        NaN
# Albany, OR             10540.0        4.0    0.0    1235.0        NaN
#
#                          a_mean  hourly
# area_title
# Abilene, TX            69437.78     NaN
# Aguadilla-Isabela, PR  45063.33     NaN
# Akron, OH              76018.00     NaN
# Albany, GA             84188.57     NaN
# Albany, OR             73312.50     NaN

# %%
##cutting out excess columns in another dataframe
df_loc_mean = groupby_data[['a_mean']]
df_loc_mean.head()
# Out:
#                          a_mean
# area_title
# Abilene, TX            69437.78
# Aguadilla-Isabela, PR  45063.33
# Akron, OH              76018.00
# Albany, GA             84188.57
# Albany, OR             73312.50
